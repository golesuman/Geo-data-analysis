# %%
! pip install networkx

# %%
import osmnx as ox
import networkx as nx

# %%
ox.config(log_console=True, use_cache=True)
place = 'Lalitpur, Nepal'
mode = 'walk'
optimizer = 'time'
tags = {'amenity': 'hospital'}
# Out:
# /home/suman/anaconda3/lib/python3.9/site-packages/osmnx/utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %%
hospital = ox.geometries_from_place(place, tags = tags )
hospital.head()
# Out:
#                         source                   geometry   amenity  \
# element_type osmid
# node         1787063191    NaN  POINT (85.33302 27.66707)  hospital
#              2164877858    NaN  POINT (85.30541 27.66566)  hospital
#              2684770935    NaN  POINT (85.31177 27.67374)  hospital
#              3047240296    NaN  POINT (85.31646 27.68738)  hospital
#              4007323130    NaN  POINT (85.33588 27.67342)  hospital
#
#                                                name emergency  \
# element_type osmid
# node         1787063191             Global hospital       NaN
#              2164877858             Public Hospital       yes
#              2684770935  Mobile Veterinary Hospital       NaN
#              3047240296                         NaN       NaN
#              4007323130                   Red Cross       NaN
#
#                                              email internet_access  \
# element_type osmid
# ...

# %%
import folium
m = folium.Map(location = [27.670101286904174, 85.32020817366065])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m1=folium.Map(width=550,height=350,location=[27.736501, 85.3300606],zoom_start=11,min_zoom=8,max_zoom=14)
# fig.add_child(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /home/suman/anaconda3/lib/python3.9/site-packages/seaborn/rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /home/suman/anaconda3/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
df = pd.read_json('export.geojson')
df.headd()
# Out:
#                 type     generator  \
# 0  FeatureCollection  overpass-ide
# 1  FeatureCollection  overpass-ide
# 2  FeatureCollection  overpass-ide
# 3  FeatureCollection  overpass-ide
# 4  FeatureCollection  overpass-ide
#
#                                            copyright  \
# 0  The data included in this document is from www...
# 1  The data included in this document is from www...
# 2  The data included in this document is from www...
# 3  The data included in this document is from www...
# 4  The data included in this document is from www...
#
#                   timestamp                                           features
# 0 2022-06-08 15:03:26+00:00  {'type': 'Feature', 'properties': {'@id': 'rel...
# 1 2022-06-08 15:03:26+00:00  {'type': 'Feature', 'properties': {'@id': 'rel...
# 2 2022-06-08 15:03:26+00:00  {'type': 'Feature', 'properties': {'@id': 'rel...
# 3 2022-06-08 15:03:26+00:00  {'type': 'Feature', 'properties': {'@id': 'rel...
# ...

# %%
df['features'].
# Out:
# 0      {'type': 'Feature', 'properties': {'@id': 'rel...
# 1      {'type': 'Feature', 'properties': {'@id': 'rel...
# 2      {'type': 'Feature', 'properties': {'@id': 'rel...
# 3      {'type': 'Feature', 'properties': {'@id': 'rel...
# 4      {'type': 'Feature', 'properties': {'@id': 'rel...
#                              ...
# 125    {'type': 'Feature', 'properties': {'@id': 'nod...
# 126    {'type': 'Feature', 'properties': {'@id': 'nod...
# 127    {'type': 'Feature', 'properties': {'@id': 'nod...
# 128    {'type': 'Feature', 'properties': {'@id': 'nod...
# 129    {'type': 'Feature', 'properties': {'@id': 'nod...
# Name: features, Length: 130, dtype: object
